# %% [markdown]
# <a href="https://colab.research.google.com/github/mihika073/Deeplearning/blob/main/Mihika_Assignment2_FFNNs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2: Trainable Parms and NN Regression (DL)
# **Dr. Dave Wanik - University of Connecticut**
#
# -----------------------------------------------
# * Student Full Name: Mihika Srivastava
# * Student ID (7 digit number): 3003306
#
#
# Let's cover some theory and application of neural networks for regression! In Q1 you will count trainable parameters. In Q2 you will read in real-world data and build, fit and evaluate a model!
#
# Students may work with their fellow classmates to complete the assignment, but each student must do their own work (i.e. write their own math and submit their own assignment for grading.) If I find that notebooks look like direct copying (i.e. copying comments and code snippets), the students involved get a 0 on the assignment. **Do your own work!**

# %% [markdown]
# # (50 points) **Q1.** Recreate the math in the `model.summmary()` below
#
# First, let's make sure you understand the concept of weights and biases.
#
# Imagine that your data set has 20,000 rows and 50 columns. You are to count the trainable parameters and show the output shape for each layer in the network (update `ABCDEFG` below using your own StudentID).
#
# **Note: if you have a 0 in your student ID, please recode it to a $5$ so that the math works out!**

# %% [markdown]
# _______________________________________________________
# ## Rubric
# Recreate the model summary above using the outputs from your own 7 digit student ID.
#
# To get full credit, no mathematical errors, correct number of weights and biases and specified, all LaTex equations are correct; bullets for each calculation are accurate and detailed enough to demonstrate mastery of the material.

# %%
# leave this as 50 for now
n_features = 50

# put your 7 digit Student ID, replace the 1234567  --3003306
# if you have a 0 in your studentID, please replace it with a 5 (so the math works out!)
A = 3
B = 5
C = 5
D = 3
E = 3
F = 5
G = 6

# %%
# now run this code
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(A, activation='relu', input_shape=(n_features,))) # see how we didnt hard code a 50 here?
model.add(Dense(B, activation='relu'))
model.add(Dense(C, activation='relu'))
model.add(Dense(D, activation='relu'))
model.add(Dense(E, activation='relu'))
model.add(Dense(F, activation='relu'))
model.add(Dense(G, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_34 (Dense)            (None, 3)                 153
#
#  dense_35 (Dense)            (None, 5)                 20
#
#  dense_36 (Dense)            (None, 5)                 30
#
#  dense_37 (Dense)            (None, 3)                 18
#
#  dense_38 (Dense)            (None, 3)                 12
#
#  dense_39 (Dense)            (None, 5)                 20
#
#  dense_40 (Dense)            (None, 6)                 36
#
#  dense_41 (Dense)            (None, 1)                 7
#
# ...
# Total params: 296
# Trainable params: 296
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make sure you add a nice subheader for each layer in the network!

# %% [markdown]
# ###Layer `dense` (153 trainable parameters, 150 weights, 3 bias)
# 150 weights and 3 bias. There are 50 inputs going into a hidden layer with 3 hidden units, and there is 1 bias for each of the 3 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $50*3 + 3 = 153$

# %% [markdown]
# ### Layer `dense1` (20 trainable parameters, 15 weights, 5 bias)
# 15 weights and 5 bias. There are 3 inputs going into a hidden layer with 5 hidden unit, and there is 1 bias for each of the 5 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $3*5 + 5 = 20$

# %% [markdown]
# ### Layer `dense2` (30 trainable parameters, 25 weights, 5 bias)
# 25 weights and 5 bias. There are 5 inputs going into a hidden layer with 5 hidden unit, and there is 1 bias for each of the 5 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $5*5 + 5 = 30$

# %% [markdown]
# ###Layer `dense3` (18 trainable parameters, 15 weights, 3 bias)
# 15 weights and 3 bias. There are 5 inputs going into a hidden layer with 3 hidden units, and there is 1 bias for each of the 3 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $5*3 + 3 = 18$

# %% [markdown]
# ###Layer `dense4` (12 trainable parameters, 9 weights, 3 bias)
# 9 weights and 3 bias. There are 3 inputs going into a hidden layer with 3 hidden units, and there is 1 bias for each of the 3 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $3*3 + 3 = 12$

# %% [markdown]
# ###Layer `dense5` (20 trainable parameters, 15 weights, 5 bias)
# 15 weights and 5 bias. There are 3 inputs going into a hidden layer with 5 hidden units, and there is 1 bias for each of the 5 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $3*5 + 3 = 20$

# %% [markdown]
# ###Layer `dense6` (36 trainable parameters, 30 weights, 6 bias)
# 30 weights and 6 bias. There are 5 inputs going into a hidden layer with 6 hidden units, and there is 1 bias for each of the 6 hidden units in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $5*6 + 6 = 36$

# %% [markdown]
# ###Layer `dense7` (7 trainable parameters, 6 weights, 1 bias)
# 6 weights and 1 bias. There are 6 inputs going into a hidden layer with 1 hidden unit, and there is 1 bias for each of the 1 hidden unit in the layer.

# %% [markdown]
# **Double click this cell to see how to make math equations with $\LaTeX$ formatting!**
#
# $6*3 + 1 = 7$

# %% [markdown]
# # (50 points) **Q2.** Fit and evaluate a model using real-world data
# I gave you (mostly) clean data to work with 😃
# These are hourly observations of weather vs. energy (electricity) consumption in New England. This is a real-world dataset you can brag about on your resume when you apply to jobs.

# %% [markdown]
# ## Rubric
# Make sure you use lots of subheaders, comments and text narrative cells so that it's easy to grade - otherwise, points off!
#
# **Prep the data (10 points):**
# * Read the energy/weather data: https://drive.google.com/file/d/1ylQJKeCyMStvvMzRGDo8nR1TI8_3xGgP/view?usp=sharing
# * Select columns for modeling
#   * Check for missing values and inspect data types
#   * The target variable is last column df['MWh']
#   * You can use as many columns for X, but you may want to just stick to df['tmpf'] through `df['sknt']` along with the df['HE'] (which is the hour of the day).
#     * A data dictionary for the weather data can be found at the bottom of this website: https://mesonet.agron.iastate.edu/request/download.phtml
#   * If you want to be an overachiever (and I think you should!), feel free to do some feature engineering (but this is optional)
# .
# * Use an 80/20 train/val split
# * Apply min/max or standard scalar to X_train and apply to X_test
#
#
# **Build, compile and fit a model (20 points)**
# * Use as many or as few layers as you would like, with as many or as few hidden units as you would like.
# * You must use  dropout and early stopping (make sure you return the best weights, you can choose what value of patience to use.)
#   * Here are some hints and a nice example of using dropout - values between 0.2 and 0.5 work well. https://machinelearningknowledge.ai/keras-dropout-layer-explained-for-beginners/
#
# **Evaluate the model (20 points):**
# * Make a learning curve for train and validation loss
# * Create a scatterplot of actual vs. predicted for each partition
# * Calculate MAE, RMSE and R2 for each partition.
# * Write five bullets about how your experience went - for example: Did you try many different architectures or did you just get lucky on your first try?  Were you nervous or excited to build your first model on real-world data. How did you ensure your model didn't overfit or underfit? Any weird patterns in the scatterplot or error metrics? Be thoughtful here.

# %%
# have fun! Use lots of subheaders and comments and make something that you are proud of

# %% [markdown]
# # **1.PREP THE DATA**

# %% [markdown]
# ## Importing the required Packages

# %%
# import modules
# for general data analysis/plotting
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# for data preperation
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# neural network modules
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping

# %% [markdown]
# ## Read the Data from the link

# %%
# https://drive.google.com/file/d/1ylQJKeCyMStvvMzRGDo8nR1TI8_3xGgP/view
# !gdown 1ylQJKeCyMStvvMzRGDo8nR1TI8_3xGgP
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ylQJKeCyMStvvMzRGDo8nR1TI8_3xGgP
# To: /content/cleanweather_energy.csv
# 100% 25.4k/25.4k [00:00<00:00, 48.2MB/s]

# %%
df = pd.read_csv('cleanweather_energy.csv')
df.shape
# Out:
# (96, 37)

# %% [markdown]
# We can see there are 96 rows and 37 columns in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   valid              96 non-null     object
#  1   station            96 non-null     object
#  2   valid.1            96 non-null     object
#  3   lon                96 non-null     float64
#  4   lat                96 non-null     float64
#  5   tmpf               96 non-null     float64
#  6   dwpf               96 non-null     float64
#  7   relh               96 non-null     float64
#  8   drct               96 non-null     float64
#  9   sknt               96 non-null     float64
#  10  p01i               96 non-null     float64
#  11  alti               96 non-null     float64
#  12  mslp               96 non-null     float64
#  13  vsby               96 non-null     float64
#  14  gust               22 non-null     float64
# ...

# %%
df.head(5)
# Out:
#                  valid station              valid.1      lon      lat  tmpf  \
# 0  2020-08-25 00:00:00     BDL  2020-08-25 00:55:00 -72.6825  41.9381  73.9
# 1  2020-08-25 01:00:00     BDL  2020-08-25 01:55:00 -72.6825  41.9381  73.9
# 2  2020-08-25 02:00:00     BDL  2020-08-25 02:55:00 -72.6825  41.9381  72.0
# 3  2020-08-25 03:00:00     BDL  2020-08-25 03:55:00 -72.6825  41.9381  73.0
# 4  2020-08-25 04:00:00     BDL  2020-08-25 04:55:00 -72.6825  41.9381  72.0
#
#    dwpf   relh   drct  sknt  ...  peak_wind_gust  peak_wind_drct  \
# 0  69.1  84.97  240.0   3.0  ...               M               M
# 1  70.0  87.63  260.0   4.0  ...               M               M
# 2  70.0  93.43  230.0   5.0  ...               M               M
# 3  70.0  90.32  230.0   5.0  ...               M               M
# 4  70.0  93.43  190.0   5.0  ...               M               M
#
#    peak_wind_time  feel                                              metar  \
# ...

# %%
df.columns
# Out:
# Index(['valid', 'station', 'valid.1', 'lon', 'lat', 'tmpf', 'dwpf', 'relh',
#        'drct', 'sknt', 'p01i', 'alti', 'mslp', 'vsby', 'gust', 'skyc1',
#        'skyc2', 'skyc3', 'skyc4', 'skyl1', 'skyl2', 'skyl3', 'skyl4',
#        'wxcodes', 'ice_accretion_1hr', 'ice_accretion_3hr',
#        'ice_accretion_6hr', 'peak_wind_gust', 'peak_wind_drct',
#        'peak_wind_time', 'feel', 'metar', 'snowdepth', 'H', 'Date', 'HE',
#        'MWh'],
#       dtype='object')

# %%
# we can see that there are some missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   valid              96 non-null     object
#  1   station            96 non-null     object
#  2   valid.1            96 non-null     object
#  3   lon                96 non-null     float64
#  4   lat                96 non-null     float64
#  5   tmpf               96 non-null     float64
#  6   dwpf               96 non-null     float64
#  7   relh               96 non-null     float64
#  8   drct               96 non-null     float64
#  9   sknt               96 non-null     float64
#  10  p01i               96 non-null     float64
#  11  alti               96 non-null     float64
#  12  mslp               96 non-null     float64
#  13  vsby               96 non-null     float64
#  14  gust               22 non-null     float64
# ...

# %% [markdown]
# We don't need to drop the rows with the missing values since this column will not be used from modeling we can skip this step.

# %% [markdown]
# ## Data frame for modelling

# %%
dfM=df[['tmpf', 'dwpf', 'relh', 'drct', 'sknt', 'HE', 'MWh']]

# %%
dfM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tmpf    96 non-null     float64
#  1   dwpf    96 non-null     float64
#  2   relh    96 non-null     float64
#  3   drct    96 non-null     float64
#  4   sknt    96 non-null     float64
#  5   HE      96 non-null     int64
#  6   MWh     96 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 5.4 KB

# %% [markdown]
# There are no categorical variables as we can see so we dont need to worry about them. We have numerical dataset.

# %%
#Check for missing values
dfM.isna().sum()
# Out:
# tmpf    0
# dwpf    0
# relh    0
# drct    0
# sknt    0
# HE      0
# MWh     0
# dtype: int64

# %% [markdown]
# There are no missing values for the dataset selected for modeling.

# %% [markdown]
# ##Summary Statistics & Percentile

# %%
dfM.describe()
# Out:
#             tmpf       dwpf        relh        drct       sknt         HE  \
# count  96.000000  96.000000   96.000000   96.000000  96.000000  96.000000
# mean   69.483333  56.632292   67.607083  291.250000   8.739583  11.500000
# std     8.234493   8.813691   21.687167   64.109282   5.284027   6.958524
# min    57.000000  37.900000   26.080000   80.000000   2.000000   0.000000
# 25%    62.100000  48.675000   49.732500  237.500000   5.000000   5.750000
# 50%    68.550000  59.000000   66.275000  320.000000   7.000000  11.500000
# 75%    75.000000  62.700000   90.400000  340.000000  11.250000  17.250000
# max    90.000000  70.000000  100.000000  360.000000  30.000000  23.000000
#
#                MWh
# count     96.00000
# mean   14443.88250
# std     2507.91228
# min    10857.18000
# 25%    12850.06750
# 50%    13903.91500
# 75%    15319.71000
# max    21359.46000

# %% [markdown]
# ##Correlation

# %%
import seaborn as sns
corr = dfM.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %%
corr = dfM.corr(method='spearman')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_055fe_row0_col0, #T_055fe_row1_col1, #T_055fe_row2_col2, #T_055fe_row3_col3, #T_055fe_row4_col4, #T_055fe_row5_col5, #T_055fe_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_055fe_row0_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_055fe_row0_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_055fe_row0_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_055fe_row0_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_055fe_row0_col5 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_055fe_row0_col6 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_055fe_row1_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_055fe_row1_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_055fe_row1_col3, #T_055fe_row2_col0, #T_055fe_row2_col4, #T_055fe_row2_col5, #T_055fe_row3_col6, #T_055fe_row4_col1, #T_055fe_row4_col2 {
# ...

# %% [markdown]
# We can see there is strong correlation between our target variable MWh and tmpf.
# drct has very less or no correlation with the target variable MWh

# %% [markdown]
# ## Data Prepration for Modeling

# %%
# Our target variable is 'MWh' , rest is our training variable in the dataset 
y = dfM['MWh']
X = dfM.drop('MWh', axis=1)
print(X.shape, y.shape)
# Out:
# (96, 6) (96,)

# %%
# convert the dataframe to numpy array
X = np.array(X)
y = np.array(y)

# %%
# split the dataset into X_train and X_test
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=12)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (76, 6) (20, 6) (76,) (20,)

# %%
# minMax scaler for scaling down the values between the range of 0 to 1
min_max_scaler = MinMaxScaler()
X_train = min_max_scaler.fit_transform(X_train)
X_test = min_max_scaler.transform(X_test)

# %% [markdown]
# # **2.BUILD COMPILE,FIT & EVALUATE THE MODEL(3 hidden layer)**

# %%
X_train.shape[1]
# Out:
# 6

# %% [markdown]
# ## Build

# %%
# build the model!
model = Sequential()
model.add(Dense(12, input_shape=(X_train.shape[1],), activation='relu')) # One layer, two times the number of input data features.
model.add(Dense(6, activation='relu')) #One layer, same number of hidden nodes as input data features.
model.add(Dense(3, activation='relu')) #Trying to use strategy -Many layers, decreasing hidden nodes by half.
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_42 (Dense)            (None, 12)                84
#
#  dense_43 (Dense)            (None, 6)                 78
#
#  dense_44 (Dense)            (None, 3)                 21
#
#  dense_45 (Dense)            (None, 1)                 4
#
# ...
# Total params: 187
# Trainable params: 187
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Visualize

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ##Compile

# %%
# compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ##Callback/Early Stopping

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=10, # you can choose a big value!
                   restore_best_weights = True) # don't forget this! otherwise it's potentially suboptimal weights

# %% [markdown]
# ##Fit the model

# %%
history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], # early stopping callbacks
                    epochs=5000, 
                    batch_size=10, 
                    shuffle=True, 
                    verbose=1)
# Out:
# Epoch 1/5000
# 8/8 [==============================] - 1s 23ms/step - loss: 204897840.0000 - mae: 14120.8994 - val_loss: 252644016.0000 - val_mae: 15670.4033
# Epoch 2/5000
# 8/8 [==============================] - 0s 6ms/step - loss: 204895856.0000 - mae: 14120.8311 - val_loss: 252642096.0000 - val_mae: 15670.3438
# Epoch 3/5000
# 8/8 [==============================] - 0s 9ms/step - loss: 204894224.0000 - mae: 14120.7734 - val_loss: 252640288.0000 - val_mae: 15670.2842
# Epoch 4/5000
# 8/8 [==============================] - 0s 6ms/step - loss: 204892608.0000 - mae: 14120.7168 - val_loss: 252638384.0000 - val_mae: 15670.2236
# Epoch 5/5000
# 8/8 [==============================] - 0s 6ms/step - loss: 204890928.0000 - mae: 14120.6562 - val_loss: 252636384.0000 - val_mae: 15670.1592
# Epoch 6/5000
# 8/8 [==============================] - 0s 7ms/step - loss: 204889088.0000 - mae: 14120.5918 - val_loss: 252634160.0000 - val_mae: 15670.0879
# Epoch 7/5000
# ...

# %% [markdown]
# ##Evaluate the model

# %% [markdown]
# ###Learning curve

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# This model seem to converge around 375 epochs without dropout

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %% [markdown]
# ###Scatterplot of actual vs predicted

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ###Model Evaluation Metrics

# %%
# metrics
pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("MAE value for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE value for test data is",mean_absolute_error(y_test, pred)) # test

print("R-squared value for training data is",r2_score(y_train, trainpreds)) # train
print("R-squared value for test data is",r2_score(y_test, pred)) # test

print("Mean squared value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean squared value for training data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE value for training data is 1507.2102785773027
# MAE value for test data is 1950.1106542968748
# R-squared value for training data is 0.2750884357065815
# R-squared value for test data is 0.1903109458320359
# Mean squared value for training data is 3985578.0975244036
# Mean squared value for training data is 5734509.067710778

# %% [markdown]
# ### Clearing the session.

# %%
from keras import backend as K
K.clear_session()

# %% [markdown]
# #3.DROPOUT(3 hidden layer)

# %%
model = Sequential()
model.add(Dense(12, input_shape=(X_train.shape[1],), activation='relu')) # (features,)
model.add(Dropout(0.2))
model.add(Dense(6, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                84
#
#  dropout (Dropout)           (None, 12)                0
#
#  dense_1 (Dense)             (None, 6)                 78
#
#  dropout_1 (Dropout)         (None, 6)                 0
#
#  dense_2 (Dense)             (None, 3)                 21
#
#  dropout_2 (Dropout)         (None, 3)                 0
#
#  dense_3 (Dense)             (None, 1)                 4
#
# ...
# Total params: 187
# Trainable params: 187
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ![graph (1).png](data:image/png;base64,...)

# %%
# compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=10, 
                   restore_best_weights = True)

# %%
#Fit the model
history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], 
                    epochs=5000, 
                    batch_size=10, 
                    shuffle=True, 
                    verbose=1)
# Out:
# Epoch 1/5000
# 8/8 [==============================] - 1s 22ms/step - loss: 204901984.0000 - mae: 14121.0498 - val_loss: 252649216.0000 - val_mae: 15670.5752
# Epoch 2/5000
# 8/8 [==============================] - 0s 6ms/step - loss: 204901072.0000 - mae: 14121.0166 - val_loss: 252647760.0000 - val_mae: 15670.5293
# Epoch 3/5000
# 8/8 [==============================] - 0s 5ms/step - loss: 204900048.0000 - mae: 14120.9834 - val_loss: 252646112.0000 - val_mae: 15670.4785
# Epoch 4/5000
# 8/8 [==============================] - 0s 6ms/step - loss: 204899200.0000 - mae: 14120.9502 - val_loss: 252644400.0000 - val_mae: 15670.4238
# Epoch 5/5000
# 8/8 [==============================] - 0s 8ms/step - loss: 204897312.0000 - mae: 14120.8896 - val_loss: 252642560.0000 - val_mae: 15670.3652
# Epoch 6/5000
# 8/8 [==============================] - 0s 6ms/step - loss: 204895024.0000 - mae: 14120.8125 - val_loss: 252640512.0000 - val_mae: 15670.2998
# Epoch 7/5000
# ...

# %%
#model evaluation
# let's see the training and validation accuracy by epoch (loss)
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# let's see the training and validation accuracy by epoch (mae)
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %%
#Actual vs Predicted Scatterplot
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ##Evaluation Metrics

# %%
#Evaluation Metrics
pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print("MAE for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE for test data is",mean_absolute_error(y_test, pred)) # test

print("R^2 value for training data is",r2_score(y_train, trainpreds)) # train
print("R^2 value for test data is",r2_score(y_test, pred)) # test

print("Mean squared value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean squared value for test data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE for training data is 2680.384680304276
# MAE for test data is 3442.3325839843756
# R^2 value for training data is -0.7463537135011047
# R^2 value for test data is -1.2610718186481997
# Mean squared value for training data is 9601487.207401145
# Mean squared value for test data is 16013723.76227488

# %% [markdown]
# # 4.BUILD COMPILE,FIT & EVALUATE THE MODEL(2 hidden layers)

# %% [markdown]
# ##Build

# %%
# build the model!
model = Sequential()
model.add(Dense(5, input_shape=(X_train.shape[1],), activation='relu')) # (features,)
model.add(Dense(3, activation='relu'))
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 5)                 35
#
#  dense_5 (Dense)             (None, 3)                 18
#
#  dense_6 (Dense)             (None, 1)                 4
#
# ...
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Visualize

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ![graph (2).png](data:image/png;base64,...)

# %% [markdown]
# ##Compile

# %%
# compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ##Callback/Early stopping

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=10, # you can choose a big value!
                   restore_best_weights = True) # don't forget this! otherwise it's potentially suboptimal weights

# %% [markdown]
# ##Fit the model

# %%
history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], # early stopping callbacks
                    epochs=5000, 
                    batch_size=10, 
                    shuffle=True, 
                    verbose=1)
# Out:
# Epoch 1/5000
# 8/8 [==============================] - 1s 23ms/step - loss: 204905584.0000 - mae: 14121.1797 - val_loss: 252652160.0000 - val_mae: 15670.6621
# Epoch 2/5000
# 8/8 [==============================] - 0s 5ms/step - loss: 204903232.0000 - mae: 14121.0986 - val_loss: 252649760.0000 - val_mae: 15670.5879
# Epoch 3/5000
# 8/8 [==============================] - 0s 5ms/step - loss: 204901568.0000 - mae: 14121.0410 - val_loss: 252647680.0000 - val_mae: 15670.5205
# Epoch 4/5000
# 8/8 [==============================] - 0s 6ms/step - loss: 204900096.0000 - mae: 14120.9902 - val_loss: 252645584.0000 - val_mae: 15670.4551
# Epoch 5/5000
# 8/8 [==============================] - 0s 8ms/step - loss: 204898448.0000 - mae: 14120.9346 - val_loss: 252643584.0000 - val_mae: 15670.3906
# Epoch 6/5000
# 8/8 [==============================] - 0s 7ms/step - loss: 204896544.0000 - mae: 14120.8682 - val_loss: 252641504.0000 - val_mae: 15670.3262
# Epoch 7/5000
# ...

# %% [markdown]
# ##Evaluate the model

# %% [markdown]
# ###Learning Curve

# %%
# let's see the training and validation accuracy by epoch
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %% [markdown]
# ###Scatterplot of actual vs predicted

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ###Model Evaluation Metrics

# %%
# metrics
pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("MAE value for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE value for test data is",mean_absolute_error(y_test, pred)) # test

print("R-squared value for training data is",r2_score(y_train, trainpreds)) # train
print("R-squared value for test data is",r2_score(y_test, pred)) # test

print("Mean squared value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean squared value for training data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE value for training data is 1499.492036903783
# MAE value for test data is 1928.9302343749998
# R-squared value for training data is 0.2982275338571597
# R-squared value for test data is 0.2225137191890132
# Mean squared value for training data is 3858358.8788941936
# Mean squared value for training data is 5506437.44580799

# %% [markdown]
# #4.**DROPOUT(2 hidden layer)**

# %%
model = Sequential()
model.add(Dense(5, input_shape=(X_train.shape[1],), activation='relu')) # (features,)
model.add(Dropout(0.2))
model.add(Dense(3, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear')) # output node
model.summary() # see what your model looks like
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 5)                 35
#
#  dropout_3 (Dropout)         (None, 5)                 0
#
#  dense_8 (Dense)             (None, 3)                 18
#
#  dropout_4 (Dropout)         (None, 3)                 0
#
#  dense_9 (Dense)             (None, 1)                 4
#
# ...
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)

# %% [markdown]
# ![graph (3).png](data:image/png;base64,...)

# %%
# compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %%
# early stopping callback
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   patience=10, 
                   restore_best_weights = True)

# %%
#Fit the model
history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    callbacks=[es], 
                    epochs=5000, 
                    batch_size=10, 
                    shuffle=True, 
                    verbose=1)
# Out:
# Epoch 1/5000
# 8/8 [==============================] - 1s 32ms/step - loss: 204874704.0000 - mae: 14120.0869 - val_loss: 252626512.0000 - val_mae: 15669.8623
# Epoch 2/5000
# 8/8 [==============================] - 0s 13ms/step - loss: 204873824.0000 - mae: 14120.0479 - val_loss: 252621664.0000 - val_mae: 15669.7080
# Epoch 3/5000
# 8/8 [==============================] - 0s 10ms/step - loss: 204868816.0000 - mae: 14119.8896 - val_loss: 252616992.0000 - val_mae: 15669.5605
# Epoch 4/5000
# 8/8 [==============================] - 0s 8ms/step - loss: 204866176.0000 - mae: 14119.7383 - val_loss: 252612096.0000 - val_mae: 15669.4062
# Epoch 5/5000
# 8/8 [==============================] - 0s 8ms/step - loss: 204853040.0000 - mae: 14119.2959 - val_loss: 252607328.0000 - val_mae: 15669.2529
# Epoch 6/5000
# 8/8 [==============================] - 0s 9ms/step - loss: 204857296.0000 - mae: 14119.4766 - val_loss: 252602624.0000 - val_mae: 15669.1064
# Epoch 7/5000
# ...

# %%
#model evaluation
# let's see the training and validation accuracy by epoch (loss)
history_dict = history.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# let's see the training and validation accuracy by epoch (mae)
history_dict = history.history
loss_values = history_dict['mae'] # you can change this
val_loss_values = history_dict['val_mae'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training mae')
plt.plot(epochs, val_loss_values, 'orange', label='Validation mae')
plt.title('Training and validation mae')
plt.xlabel('Epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %%
#Actual vs Predicted Scatterplot
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ##Evaluation Metrics

# %%
#Evaluation Metrics
pred = model.predict(X_test)
pred

trainpreds = model.predict(X_train)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print("MAE for training data is",mean_absolute_error(y_train, trainpreds)) # train
print("MAE for test data is",mean_absolute_error(y_test, pred)) # test

print("R^2 value for training data is",r2_score(y_train, trainpreds)) # train
print("R^2 value for test data is",r2_score(y_test, pred)) # test

print("Mean squared value for training data is",mean_squared_error(y_train, trainpreds)) # train
print("Mean squared value for test data is",mean_squared_error(y_test, pred)) # test
# Out:
# MAE for training data is 3214.731650390625
# MAE for test data is 4089.946644531251
# R^2 value for training data is -1.3828451089129397
# R^2 value for test data is -1.9922148184474757
# Mean squared value for training data is 13100929.470111901
# Mean squared value for test data is 21191941.42566008

# %% [markdown]
# #**FINDINGS**

# %% [markdown]
# I ran several model by changing different parameters and hyperparameters with different architecture. I was both nervous and excited at the same time. For me it was a long but interesting and insightfull process.
# The best model I came up with was the model will 2 hidden layes with 5 & 3 nodes respectively (Rmsprop optimizer)
#
# For keeping the notebook concise, I kept 4 models-
# a- 3 hidden layers without dropout
# b- 3 hidden layers with dropout
# **c- 2 hidden layers without dropout** (best model so far)
# d- 2 hidden layers with dropout
#
# The general finding were-
#
# 1- Keeping a funnel shape neural network, i.e keeping less number of nodes in the hidden layers and gradually decreasing them performed better with this dataset.
#
# 2- The model with the less number of layers performed best for this dataset.
#
# 3- RMSPROP optimizer gave better results as compared to SGD.
#
# 4- To ensure that the model should not overfit or underfit, I was constantly checking if the model is providing both low bias and low variance.
#
# 5- By using dropoff the number of epochs increased significantly. I tried different values of dropoff but they were not giving good results for this dataset.
#
# 6- I used different batch size and got best results with batch size 10. (Maybe because the dataset is not that big)
